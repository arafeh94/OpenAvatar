# %%
import asyncio
from pympler import asizeof
import gc
from core.plugins.lip_sync.core.avatar_extentions import AvatarManager
import os
os.environ["ELEVENLABS_API_KEY"]="sk_6f0d166f123de1b5153726721d78fd47320a71b8277c1a69"
avatar_manager = AvatarManager()

# %%
buffer1 = avatar_manager.tts_buffer("lisa_casual_720_pl", 'Hello how are youHello how are youHello how are youHello how are youHello how are youHello how are you')

# %%
buffer2 = avatar_manager.tts_buffer("mag", 'Hello how are youHello how are youHello how are youHello how are youHello how are youHello how are you')

# %%
buffer3 = avatar_manager.tts_buffer("police", 'Hello how are youHello how are youHello how are youHello how are youHello how are youHello how are you')

# %%
frames, audio, text = next(buffer2)
for frame in frames:
    print(frame)
print(audio)
print(text)
# Out:
# [[[14 14 21]
#   [14 14 21]
#   [14 14 21]
#   ...
#   [83 79 82]
#   [82 78 81]
#   [87 83 86]]
#
#  [[14 14 21]
#   [14 14 21]
#   [14 14 21]
#   ...
#   [83 79 82]
#   [82 78 81]
#   [87 83 86]]
#
#  [[14 14 21]
#   [14 14 21]
#   [14 14 21]
#   ...
#   [83 79 82]
#   [82 78 81]
#   [88 84 87]]
#
#  ...
#
#  [[18 20 36]
#   [15 17 33]
#   [16 18 34]
#   ...
#   [41 45 61]
#   [41 45 61]
#   [43 47 63]]
#
#  [[18 20 36]
#   [15 17 33]
#   [17 19 35]
#   ...
#   [39 43 59]
#   [41 45 61]
#   [43 47 63]]
#
#  [[17 19 35]
#   [15 17 33]
#   [17 19 35]
#   ...
#   [39 43 59]
#   [41 45 61]
#   [43 47 63]]]
# [[[14 14 21]
#   [14 14 21]
#   [14 14 21]
#   ...
#   [83 79 82]
#   [82 78 81]
#   [87 83 86]]
#
#  [[14 14 21]
#   [14 14 21]
#   [14 14 21]
#   ...
#   [83 79 82]
#   [82 78 81]
#   [87 83 86]]
#
#  [[14 14 21]
#   [14 14 21]
#   [14 14 21]
#   ...
#   [83 79 82]
#   [82 78 81]
#   [88 84 87]]
#
#  ...
#
#  [[16 20 36]
#   [14 18 34]
#   [14 18 34]
#   ...
#   [41 45 61]
# ...

# %%
for frame in frames:
    print(frame)

# %%
buffer1.stop()
buffer2.stop()
buffer3.stop()

# %%
print(frames)

# %%
gc.collect()
# Out:
# 0

# %%
del  audio
